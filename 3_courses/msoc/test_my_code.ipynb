# %% [markdown]
# <img src='https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/tools/frameworks/-/raw/main/img/MSOC_banner.png' align='right' width='100%'/>

# %% [markdown]
# <a href="./Index.ipynb">Index</a>

# %% [markdown]
# **Copyright:** 2026 European Union <br>
# **License:** MIT <br>
# **Authors:** Ben Loveday (EUMETSAT/Innoflair UG)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Multi-Sensor Ocean Colour Course</h3></div>
# <hr>

# %% [markdown]
# Welcome to the MSOC environment test code module, **test_my_code**. If you have not used Jupyter Notebook before, we suggest that you review the <a href="../../working-with-python/Intro_to_Python_and_Jupyter.ipynb" target="_blank">Introduction to Python and Project Jupyter<a> notebook in the *working-with-python* submodule folder or the <a href="https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Running%20Code.html" taget="_blank">"Running code"</a> section of the Jupyter Notebook Read the Docs.
#
# The code in this notebook is in a single block below. The best way to run this is by selecting the *"Restart Kernel and Run All Cells"* option from the **Kernel** option in the menu bar at the top of the screen. If all goes well, and the correct environment is activated with all the necessary packages, then there should be no problem below. If there is, we will sort it out in the technical check.
#
# By default, you should have activated the **cmts_ocean_colour_applications** environment.

# %%
import sys
import os
print(f"\nYour environment is: {sys.executable.split(os.sep)[-3]}")

try:
    import numpy
    import earthaccess
    import cartopy
    import ipywidgets
    import ipympl
    import matplotlib
    import netCDF4
    import skimage
    import scipy
    import shapely
    import xarray
    import copernicusmarine
    import pandas
    import pyinterp
    import seaborn
    import hda
    import rasterio
    import rioxarray
    import eumartools
    import eumdac
    import bs4
    import cdsapi
    import ephem
    import urllib3
    print("---\nYour packages installed correctly. You are good to go!\n---")    
except:
    print("---\nYour packages did not install correctly, please check that you have the msoc environment activated. If it is, please record this information.\n---")

print("If requested, please update the installation checklist spreadsheet for the course with this information")
# Out:
# Your environment is: cmts_ocean_colour_applications
# ---
# Your packages installed correctly. You are good to go!
# ---
# If requested, please update the installation checklist spreadsheet for the course with this information

# %% [markdown]
# <hr>
# <a href="./Index.ipynb">Index</a>
# <hr>
# <a href="https://gitlab.eumetsat.int/eumetlab/ocean">View on GitLab</a> | <a href="https://training.eumetsat.int/">EUMETSAT Training</a> | <a href=mailto:ops@eumetsat.int>Contact helpdesk for support </a> | <a href=mailto:.training@eumetsat.int>Contact our training team to collaborate on and reuse this material</a></span></p>

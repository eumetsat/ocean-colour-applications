# %% [markdown]
# <img src='https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/tools/frameworks/-/raw/main/img/MSOC_banner.png' align='right' width='100%'/>

# %% [markdown]
# <a href="../Index.ipynb">Index</a>

# %% [markdown]
# **Copyright:** 2025 MSOC training team <br>
# **License:** MIT <br>
# **Authors:** Anna Windle diPaolo (NASA), Carina Poulin (NASA), Ben Loveday (EUMETSAT/Innoflair UG)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Multi-sensor Ocean Colour Course</h3></div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# This notebook has the following prerequisites:
# - **<a href="https://urs.earthdata.nasa.gov/" target="_blank">An EarthData account</a>** if you are using or plan to use EarthData to download PACE OCI data.
#
# </div>
# <hr>

# %% [markdown]
# # Applying Gaussian Pigment (GPig) Phytoplankton Community Composition Algorithm to OCI data
#
# The **<a href="../submodules/pace-2025/book/presentations/notebooks/oci_gpig.ipynb" target="_blank">Applying Gaussian Pigment (GPig) Phytoplankton Community Composition Algorithm to OCI data</a>** notebook, can be found in the pace-2025 submodule.

# %% [markdown]
# <hr>
# <a href="../Index.ipynb">Index</a>
# <hr>
# <a href="https://gitlab.com/eo_training/msoc" target="_blank">View on GitLab</a> | <a href="https://training.eumetsat.int/" target="_blank">EUMETSAT Training</a> | <a href=mailto:ops@eumetsat.int target="_blank">Contact helpdesk for support </a> | <a href=mailto:training@eumetsat.int target="_blank">Contact our training team to collaborate on and reuse this material</a></span></p>
